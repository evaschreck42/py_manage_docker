# %%
from urllib.request import urlopen

html = urlopen('https://www.beuth.de/de/norm/iso-iec-25012/115477103')
print(html.read())
# Out:
# b'    \n\n<!DOCTYPE html>\n<html lang="de">\n<head>\n<meta charset="UTF-8" />\n<title>ISO/IEC 25012 - 2008-12 - Beuth.de</title>\n<meta name="keywords" content=\'ISO/IEC,25012,Software,Engineering,Qualit\xc3\xa4tskriterien,Bewertung,Softwareprodukten,SQuaRE,Modell,Datenqualit\xc3\xa4t\' />\n<link rel="shortcut icon" type="image/x-icon" href="https://www.beuth.de/resource/blob/264558/4cf339e13e2292d3e0390ae064d616e9/beuth-de-favicon.ico"/>\n<link rel="alternate" hreflang="de" href="https://www.beuth.de/de/norm/iso-iec-25012/115477103"/>\n<link rel="alternate" hreflang="en" href="https://www.beuth.de/en/standard/iso-iec-25012/115477103"/>\n<link rel="alternate" hreflang="x-default" href="https://www.beuth.de/de/norm/iso-iec-25012/115477103"/>\n<meta name="description" content="ISO/IEC 25012 - 2008-12 Software-Engineering\xc2\xa0- Qualit\xc3\xa4tskriterien und Bewertung von Softwareprodukten (SQuaRE)\xc2\xa0- Modell der Datenqualit\xc3\xa4t. Jetzt informieren!" />\n<meta name="robots" c
# ...
